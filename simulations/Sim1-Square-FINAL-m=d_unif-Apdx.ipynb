# %% [markdown]
# # Introduction
#
# * This code is adapted from the example provided in the python optimal transport package (POT)
#
# This notebook presents the results of mapping a 2D uniform input distribution to a 2D uniform target distribution.

# %% [markdown]
# ## Imports

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as pl
import matplotlib.animation as animation
import torch
from torch import nn
import ot
import scipy
import random
# import sys
# !{sys.executable} -m pip install pot

use_cuda = torch.cuda.is_available()
if use_cuda:
    print('__CUDNN VERSION:', torch.backends.cudnn.version())
    print('__Number CUDA Devices:', torch.cuda.device_count())
    print('__CUDA Device Name:',torch.cuda.get_device_name(0))
    print('__CUDA Device Total Memory [GB]:',torch.cuda.get_device_properties(0).total_memory/1e9)

seed = 126
torch.manual_seed(seed) # make chunk execution consistent
# Out:
# __CUDNN VERSION: 8902
# __Number CUDA Devices: 1
# __CUDA Device Name: NVIDIA GeForce RTX 4080
# __CUDA Device Total Memory [GB]: 16.860184576

# %% [markdown]
# ## Data generation

# %%
torch.manual_seed(seed) # make chunk execution consistent 

sigma = 0.0
n_dims = 2
n_features = 2

def get_data(n_samples):
    # c = torch.rand(size=(n_samples, 2))
    c1 = torch.arange(1, n_samples+1) / (n_samples)# .reshape((n_samples, 1)) / (n_samples)
    c2 = torch.arange(1, n_samples+1) / (n_samples)# .reshape((n_samples, 1)) / (n_samples)
    c = torch.cartesian_prod(c1,c2)
    x = c
    return x

def get_data_normal(n_samples):
    c = torch.randn(n_samples**2, 2) # match previous
    # c = 1/(1+torch.exp(-0.5*c))
    x = c
    return x

def get_data_sobol(n_samples):
    a = scipy.stats.qmc.Sobol(d=2, scramble=True, optimization='lloyd')
    c = torch.tensor(a.random_base2(m=n_samples)).float()
    return c


# empirical fill-based loss  
from scipy.spatial.distance import cdist
def fill_distance(data, fitted, type='max'): 
    m = torch.tensor(cdist(data, fitted, 'euclidean')) 
    # m = cdist(data, fitted, 'euclidean')
    min, min_indices = torch.min(m, dim=1) # min across rows 
    if type=='max':
        fill_dist = max(min)
    elif type=='mean':
        fill_dist = torch.mean(min)
    else:
        fill_dist = max(min)

    return fill_dist.item() # get actual float

# %% [markdown]
# ## Plot data

# %%
torch.manual_seed(seed) # make chunk execution consistent 

# plot the distributions
x = get_data(10)
pl.figure(1)
pl.scatter(x[:, 0], x[:, 1], label='Data samples from $\mu_d$', alpha=0.5)
pl.title('Data Distribution')
pl.legend()

# %% [markdown]
# ## Generator Model

# %%
torch.manual_seed(seed) # make chunk execution consistent 

class Generator(torch.nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        self.n_features = 2
        self.n_out = 2
        n= 200
        leaky = 0.0001
        self.model = nn.Sequential( 
            nn.Linear(self.n_features, n),
            nn.LeakyReLU(leaky),
            nn.Linear(n, n),
            nn.LeakyReLU(leaky),
            nn.Linear(n, n),
            nn.LeakyReLU(leaky),
            nn.Linear(n, n),
            nn.LeakyReLU(leaky),
            nn.Linear(n, n),
            nn.LeakyReLU(leaky),
            nn.Linear(n, self.n_out),
        )
    def forward(self, x):
        x = self.model(x)
        return x
    
class Generator2(torch.nn.Module):
    def __init__(self):
        super(Generator2, self).__init__()
        self.n_features = 2
        self.n_out = 2
        n= 10 
        leaky = 0.0001
        self.model = nn.Sequential( 
            nn.Linear(self.n_features, n),
            nn.LeakyReLU(leaky),
            nn.Linear(n, n),
            nn.LeakyReLU(leaky),
            nn.Linear(n, self.n_out),
        )
    def forward(self, x):
        x = self.model(x)
        return x
    
g1 = Generator()
g2 = Generator2()
num_hidden_layers = sum(1 for _ in g1.modules() if isinstance(_, nn.Linear))
print(f"The number of hidden layers in G1 is: {num_hidden_layers}")
num_hidden_layers = sum(1 for _ in g2.modules() if isinstance(_, nn.Linear))
print(f"The number of hidden layers in G2 is: {num_hidden_layers}")
# Out:
# The number of hidden layers in G1 is: 6
# The number of hidden layers in G2 is: 3

# %% [markdown]
# ## Training the model

# %%
torch.manual_seed(seed) # make chunk execution consistent 

G = Generator2()
optimizer = torch.optim.RMSprop(G.parameters(), lr=0.00019, eps=1e-6)
# optimizer = torch.optim.RMSprop(G.parameters(), lr=0.00019, eps=1e-5, weight_decay=1e-15)

# number of iteration and size of the batches
n_iter = 10000
size_batch = 30 # need to square this to facilitate cartesian product in get_data()

# generate static samples to see their trajectory along training
n_visu = size_batch**2
# grid input for visualization
c1 = torch.arange(1, size_batch+1) / (size_batch)# .reshape((n_samples, 1)) / (n_samples)
c2 = torch.arange(1, size_batch+1) / (size_batch)# .reshape((n_samples, 1)) / (n_samples)
c = torch.cartesian_prod(c1,c2)
xnvisu = c
# xnvisu = torch.rand(size_batch**2, 2)

xvisu = torch.zeros(n_iter, size_batch**2, n_dims)
ab = torch.ones(size_batch**2) / size_batch**2 
losses = []
fill_losses = []

# train mode
G.train()

# generate data samples
xd = get_data(size_batch)

for i in range(n_iter):

    # generate noise samples
    xn = torch.rand(size_batch**2, n_features) # random sample every iteration 
    # xn = get_data(size_batch) # for uniform grid

    # generate data samples
    # xd = get_data_normal(size_batch)

    # generate sample along iterations
    G.eval()
    xvisu[i, :, :] = G(xnvisu).detach()

    # generate samples and compute distance matrix
    G.train()
    xg = G(xn)

    M = ot.dist(xg, xd)
    loss = ot.emd2(ab, ab, M)
    losses.append(float(loss.detach()))
    # print(losses)

    fill_loss = fill_distance(xd.detach().numpy(), xg.detach().numpy(), type='mean')
    fill_losses.append(fill_loss)

    if i % 10 == 0:
        # print("Iter: {:3d}, loss={}".format(i, losses[-1]))
        print(f"Iter: {i}, \t wass-loss={round(losses[-1], 5)}, \t fill-dist={round(fill_loss, 5)}")

    loss.backward()
    optimizer.step()

    del M

# wasserstein loss 
pl.figure(2)
pl.semilogy(losses)
pl.grid()
pl.title('Wasserstein distance')
pl.xlabel("Iterations")

# fill distance 
pl.figure(3)
pl.semilogy(fill_losses)
pl.grid()
pl.title('Space Filling distance (Mean)')
pl.xlabel("Iterations")
# Out:
# Iter: 0, 	 wass-loss=0.8758, 	 fill-dist=0.78533
# Iter: 10, 	 wass-loss=0.65861, 	 fill-dist=0.65155
# Iter: 20, 	 wass-loss=0.55728, 	 fill-dist=0.58353
# Iter: 30, 	 wass-loss=0.47009, 	 fill-dist=0.52949
# Iter: 40, 	 wass-loss=0.40688, 	 fill-dist=0.47874
# Iter: 50, 	 wass-loss=0.36064, 	 fill-dist=0.4376
# Iter: 60, 	 wass-loss=0.31214, 	 fill-dist=0.40693
# Iter: 70, 	 wass-loss=0.27497, 	 fill-dist=0.37966
# Iter: 80, 	 wass-loss=0.24433, 	 fill-dist=0.36004
# Iter: 90, 	 wass-loss=0.21512, 	 fill-dist=0.33522
# Iter: 100, 	 wass-loss=0.19215, 	 fill-dist=0.32058
# Iter: 110, 	 wass-loss=0.17013, 	 fill-dist=0.30418
# Iter: 120, 	 wass-loss=0.15315, 	 fill-dist=0.29057
# Iter: 130, 	 wass-loss=0.13851, 	 fill-dist=0.28445
# Iter: 140, 	 wass-loss=0.12899, 	 fill-dist=0.27418
# Iter: 150, 	 wass-loss=0.11783, 	 fill-dist=0.26731
# Iter: 160, 	 wass-loss=0.1131, 	 fill-dist=0.2635
# Iter: 170, 	 wass-loss=0.10747, 	 fill-dist=0.26063
# Iter: 180, 	 wass-loss=0.10515, 	 fill-dist=0.25785
# Iter: 190, 	 wass-loss=0.10452, 	 fill-dist=0.25612
# Iter: 200, 	 wass-loss=0.10503, 	 fill-dist=0.25573
# Iter: 210, 	 wass-loss=0.10578, 	 fill-dist=0.25586
# Iter: 220, 	 wass-loss=0.11222, 	 fill-dist=0.2582
# Iter: 230, 	 wass-loss=0.11798, 	 fill-dist=0.25757
# Iter: 240, 	 wass-loss=0.12308, 	 fill-dist=0.2579
# Iter: 250, 	 wass-loss=0.12823, 	 fill-dist=0.26025
# Iter: 260, 	 wass-loss=0.1365, 	 fill-dist=0.26286
# Iter: 270, 	 wass-loss=0.14368, 	 fill-dist=0.26359
# Iter: 280, 	 wass-loss=0.14851, 	 fill-dist=0.26478
# Iter: 290, 	 wass-loss=0.15957, 	 fill-dist=0.2661
# Iter: 300, 	 wass-loss=0.16048, 	 fill-dist=0.26983
# Iter: 310, 	 wass-loss=0.16165, 	 fill-dist=0.26928
# Iter: 320, 	 wass-loss=0.17891, 	 fill-dist=0.26982
# Iter: 330, 	 wass-loss=0.17772, 	 fill-dist=0.2731
# Iter: 340, 	 wass-loss=0.18376, 	 fill-dist=0.27254
# Iter: 350, 	 wass-loss=0.17617, 	 fill-dist=0.27206
# Iter: 360, 	 wass-loss=0.18058, 	 fill-dist=0.27497
# Iter: 370, 	 wass-loss=0.18291, 	 fill-dist=0.27349
# Iter: 380, 	 wass-loss=0.1832, 	 fill-dist=0.27505
# Iter: 390, 	 wass-loss=0.17232, 	 fill-dist=0.27406
# Iter: 400, 	 wass-loss=0.17483, 	 fill-dist=0.27261
# Iter: 410, 	 wass-loss=0.17073, 	 fill-dist=0.27315
# Iter: 420, 	 wass-loss=0.15841, 	 fill-dist=0.27195
# Iter: 430, 	 wass-loss=0.1581, 	 fill-dist=0.27172
# Iter: 440, 	 wass-loss=0.14839, 	 fill-dist=0.27221
# Iter: 450, 	 wass-loss=0.14449, 	 fill-dist=0.2721
# Iter: 460, 	 wass-loss=0.14646, 	 fill-dist=0.27186
# Iter: 470, 	 wass-loss=0.13915, 	 fill-dist=0.26999
# Iter: 480, 	 wass-loss=0.13495, 	 fill-dist=0.26701
# Iter: 490, 	 wass-loss=0.12963, 	 fill-dist=0.2653
# Iter: 500, 	 wass-loss=0.1227, 	 fill-dist=0.26389
# Iter: 510, 	 wass-loss=0.1224, 	 fill-dist=0.25973
# Iter: 520, 	 wass-loss=0.11881, 	 fill-dist=0.25715
# Iter: 530, 	 wass-loss=0.1176, 	 fill-dist=0.25596
# Iter: 540, 	 wass-loss=0.11638, 	 fill-dist=0.25465
# Iter: 550, 	 wass-loss=0.11249, 	 fill-dist=0.25167
# Iter: 560, 	 wass-loss=0.11309, 	 fill-dist=0.24894
# Iter: 570, 	 wass-loss=0.11215, 	 fill-dist=0.24797
# Iter: 580, 	 wass-loss=0.11101, 	 fill-dist=0.24523
# Iter: 590, 	 wass-loss=0.11191, 	 fill-dist=0.24496
# Iter: 600, 	 wass-loss=0.11348, 	 fill-dist=0.24161
# Iter: 610, 	 wass-loss=0.11542, 	 fill-dist=0.24158
# Iter: 620, 	 wass-loss=0.1141, 	 fill-dist=0.23671
# Iter: 630, 	 wass-loss=0.11264, 	 fill-dist=0.23701
# Iter: 640, 	 wass-loss=0.11647, 	 fill-dist=0.23686
# Iter: 650, 	 wass-loss=0.11233, 	 fill-dist=0.23105
# Iter: 660, 	 wass-loss=0.11343, 	 fill-dist=0.23128
# Iter: 670, 	 wass-loss=0.10761, 	 fill-dist=0.23193
# Iter: 680, 	 wass-loss=0.10821, 	 fill-dist=0.23204
# Iter: 690, 	 wass-loss=0.10567, 	 fill-dist=0.22835
# Iter: 700, 	 wass-loss=0.10951, 	 fill-dist=0.22911
# Iter: 710, 	 wass-loss=0.10752, 	 fill-dist=0.22951
# Iter: 720, 	 wass-loss=0.10573, 	 fill-dist=0.23262
# Iter: 730, 	 wass-loss=0.10147, 	 fill-dist=0.23145
# Iter: 740, 	 wass-loss=0.1023, 	 fill-dist=0.23007
# Iter: 750, 	 wass-loss=0.10447, 	 fill-dist=0.22979
# Iter: 760, 	 wass-loss=0.09969, 	 fill-dist=0.229
# Iter: 770, 	 wass-loss=0.10232, 	 fill-dist=0.23034
# Iter: 780, 	 wass-loss=0.10008, 	 fill-dist=0.23028
# Iter: 790, 	 wass-loss=0.10226, 	 fill-dist=0.22952
# Iter: 800, 	 wass-loss=0.09781, 	 fill-dist=0.2309
# Iter: 810, 	 wass-loss=0.09617, 	 fill-dist=0.23019
# Iter: 820, 	 wass-loss=0.09723, 	 fill-dist=0.23163
# Iter: 830, 	 wass-loss=0.09378, 	 fill-dist=0.23152
# Iter: 840, 	 wass-loss=0.09375, 	 fill-dist=0.23178
# Iter: 850, 	 wass-loss=0.09432, 	 fill-dist=0.23236
# Iter: 860, 	 wass-loss=0.09349, 	 fill-dist=0.23295
# Iter: 870, 	 wass-loss=0.09289, 	 fill-dist=0.23308
# Iter: 880, 	 wass-loss=0.09226, 	 fill-dist=0.2329
# Iter: 890, 	 wass-loss=0.09272, 	 fill-dist=0.23303
# Iter: 900, 	 wass-loss=0.09263, 	 fill-dist=0.23278
# Iter: 910, 	 wass-loss=0.09485, 	 fill-dist=0.23298
# Iter: 920, 	 wass-loss=0.09356, 	 fill-dist=0.23184
# Iter: 930, 	 wass-loss=0.09638, 	 fill-dist=0.2318
# Iter: 940, 	 wass-loss=0.09272, 	 fill-dist=0.23055
# Iter: 950, 	 wass-loss=0.09162, 	 fill-dist=0.22916
# Iter: 960, 	 wass-loss=0.09476, 	 fill-dist=0.22733
# Iter: 970, 	 wass-loss=0.08967, 	 fill-dist=0.22551
# Iter: 980, 	 wass-loss=0.08957, 	 fill-dist=0.22238
# Iter: 990, 	 wass-loss=0.08706, 	 fill-dist=0.21963
# Iter: 1000, 	 wass-loss=0.0867, 	 fill-dist=0.21668
# Iter: 1010, 	 wass-loss=0.08936, 	 fill-dist=0.21343
# Iter: 1020, 	 wass-loss=0.08311, 	 fill-dist=0.20931
# Iter: 1030, 	 wass-loss=0.07967, 	 fill-dist=0.20555
# Iter: 1040, 	 wass-loss=0.07615, 	 fill-dist=0.2024
# Iter: 1050, 	 wass-loss=0.07534, 	 fill-dist=0.19876
# Iter: 1060, 	 wass-loss=0.07365, 	 fill-dist=0.1946
# Iter: 1070, 	 wass-loss=0.06973, 	 fill-dist=0.19064
# Iter: 1080, 	 wass-loss=0.06943, 	 fill-dist=0.18744
# Iter: 1090, 	 wass-loss=0.06653, 	 fill-dist=0.18445
# Iter: 1100, 	 wass-loss=0.06339, 	 fill-dist=0.18094
# Iter: 1110, 	 wass-loss=0.06286, 	 fill-dist=0.17875
# Iter: 1120, 	 wass-loss=0.06062, 	 fill-dist=0.17663
# Iter: 1130, 	 wass-loss=0.05897, 	 fill-dist=0.17346
# Iter: 1140, 	 wass-loss=0.05997, 	 fill-dist=0.17133
# Iter: 1150, 	 wass-loss=0.05841, 	 fill-dist=0.16967
# Iter: 1160, 	 wass-loss=0.05754, 	 fill-dist=0.16791
# Iter: 1170, 	 wass-loss=0.05685, 	 fill-dist=0.1667
# Iter: 1180, 	 wass-loss=0.05798, 	 fill-dist=0.1655
# Iter: 1190, 	 wass-loss=0.05718, 	 fill-dist=0.16505
# Iter: 1200, 	 wass-loss=0.05772, 	 fill-dist=0.16269
# Iter: 1210, 	 wass-loss=0.05779, 	 fill-dist=0.16071
# Iter: 1220, 	 wass-loss=0.05738, 	 fill-dist=0.15873
# Iter: 1230, 	 wass-loss=0.05961, 	 fill-dist=0.15766
# Iter: 1240, 	 wass-loss=0.05846, 	 fill-dist=0.15583
# Iter: 1250, 	 wass-loss=0.05658, 	 fill-dist=0.15329
# Iter: 1260, 	 wass-loss=0.05866, 	 fill-dist=0.14981
# Iter: 1270, 	 wass-loss=0.05859, 	 fill-dist=0.14876
# Iter: 1280, 	 wass-loss=0.0582, 	 fill-dist=0.14497
# Iter: 1290, 	 wass-loss=0.05627, 	 fill-dist=0.1425
# Iter: 1300, 	 wass-loss=0.05862, 	 fill-dist=0.13935
# Iter: 1310, 	 wass-loss=0.0557, 	 fill-dist=0.13672
# Iter: 1320, 	 wass-loss=0.05585, 	 fill-dist=0.13424
# Iter: 1330, 	 wass-loss=0.0546, 	 fill-dist=0.13045
# Iter: 1340, 	 wass-loss=0.05231, 	 fill-dist=0.12536
# Iter: 1350, 	 wass-loss=0.05025, 	 fill-dist=0.12299
# Iter: 1360, 	 wass-loss=0.04991, 	 fill-dist=0.11936
# Iter: 1370, 	 wass-loss=0.04495, 	 fill-dist=0.11583
# Iter: 1380, 	 wass-loss=0.04598, 	 fill-dist=0.11361
# Iter: 1390, 	 wass-loss=0.04402, 	 fill-dist=0.10974
# Iter: 1400, 	 wass-loss=0.04089, 	 fill-dist=0.10665
# Iter: 1410, 	 wass-loss=0.03922, 	 fill-dist=0.10483
# Iter: 1420, 	 wass-loss=0.03999, 	 fill-dist=0.10276
# Iter: 1430, 	 wass-loss=0.03857, 	 fill-dist=0.10057
# Iter: 1440, 	 wass-loss=0.03466, 	 fill-dist=0.09793
# Iter: 1450, 	 wass-loss=0.03603, 	 fill-dist=0.09451
# Iter: 1460, 	 wass-loss=0.0316, 	 fill-dist=0.09291
# Iter: 1470, 	 wass-loss=0.03224, 	 fill-dist=0.09098
# Iter: 1480, 	 wass-loss=0.0322, 	 fill-dist=0.0889
# Iter: 1490, 	 wass-loss=0.03114, 	 fill-dist=0.08825
# Iter: 1500, 	 wass-loss=0.03004, 	 fill-dist=0.08554
# Iter: 1510, 	 wass-loss=0.03017, 	 fill-dist=0.08442
# Iter: 1520, 	 wass-loss=0.02745, 	 fill-dist=0.08295
# Iter: 1530, 	 wass-loss=0.03272, 	 fill-dist=0.08155
# Iter: 1540, 	 wass-loss=0.02639, 	 fill-dist=0.07893
# Iter: 1550, 	 wass-loss=0.0289, 	 fill-dist=0.07986
# Iter: 1560, 	 wass-loss=0.0275, 	 fill-dist=0.07689
# Iter: 1570, 	 wass-loss=0.02799, 	 fill-dist=0.07578
# Iter: 1580, 	 wass-loss=0.02927, 	 fill-dist=0.07497
# Iter: 1590, 	 wass-loss=0.02605, 	 fill-dist=0.07143
# Iter: 1600, 	 wass-loss=0.02574, 	 fill-dist=0.07061
# Iter: 1610, 	 wass-loss=0.02501, 	 fill-dist=0.06975
# Iter: 1620, 	 wass-loss=0.0227, 	 fill-dist=0.06732
# Iter: 1630, 	 wass-loss=0.02184, 	 fill-dist=0.06499
# Iter: 1640, 	 wass-loss=0.02173, 	 fill-dist=0.06458
# Iter: 1650, 	 wass-loss=0.02329, 	 fill-dist=0.06348
# Iter: 1660, 	 wass-loss=0.02307, 	 fill-dist=0.0609
# Iter: 1670, 	 wass-loss=0.02127, 	 fill-dist=0.05924
# Iter: 1680, 	 wass-loss=0.01841, 	 fill-dist=0.05693
# Iter: 1690, 	 wass-loss=0.02157, 	 fill-dist=0.05628
# Iter: 1700, 	 wass-loss=0.01831, 	 fill-dist=0.05508
# Iter: 1710, 	 wass-loss=0.02012, 	 fill-dist=0.05229
# Iter: 1720, 	 wass-loss=0.01795, 	 fill-dist=0.05021
# Iter: 1730, 	 wass-loss=0.01657, 	 fill-dist=0.0488
# Iter: 1740, 	 wass-loss=0.01679, 	 fill-dist=0.04715
# Iter: 1750, 	 wass-loss=0.01524, 	 fill-dist=0.04562
# Iter: 1760, 	 wass-loss=0.01376, 	 fill-dist=0.04307
# Iter: 1770, 	 wass-loss=0.01398, 	 fill-dist=0.0429
# Iter: 1780, 	 wass-loss=0.01369, 	 fill-dist=0.04099
# Iter: 1790, 	 wass-loss=0.01339, 	 fill-dist=0.039
# Iter: 1800, 	 wass-loss=0.01198, 	 fill-dist=0.03706
# Iter: 1810, 	 wass-loss=0.01223, 	 fill-dist=0.03554
# Iter: 1820, 	 wass-loss=0.01192, 	 fill-dist=0.03432
# Iter: 1830, 	 wass-loss=0.01058, 	 fill-dist=0.03299
# Iter: 1840, 	 wass-loss=0.01226, 	 fill-dist=0.03184
# Iter: 1850, 	 wass-loss=0.01187, 	 fill-dist=0.03252
# Iter: 1860, 	 wass-loss=0.01032, 	 fill-dist=0.02982
# Iter: 1870, 	 wass-loss=0.01137, 	 fill-dist=0.02973
# Iter: 1880, 	 wass-loss=0.00993, 	 fill-dist=0.02759
# Iter: 1890, 	 wass-loss=0.00974, 	 fill-dist=0.02696
# Iter: 1900, 	 wass-loss=0.01154, 	 fill-dist=0.02647
# Iter: 1910, 	 wass-loss=0.01154, 	 fill-dist=0.02587
# Iter: 1920, 	 wass-loss=0.0134, 	 fill-dist=0.02516
# Iter: 1930, 	 wass-loss=0.00904, 	 fill-dist=0.02423
# Iter: 1940, 	 wass-loss=0.00987, 	 fill-dist=0.02368
# Iter: 1950, 	 wass-loss=0.01125, 	 fill-dist=0.02317
# Iter: 1960, 	 wass-loss=0.00756, 	 fill-dist=0.02295
# Iter: 1970, 	 wass-loss=0.01013, 	 fill-dist=0.02287
# Iter: 1980, 	 wass-loss=0.00992, 	 fill-dist=0.02321
# Iter: 1990, 	 wass-loss=0.00918, 	 fill-dist=0.02277
# Iter: 2000, 	 wass-loss=0.0079, 	 fill-dist=0.02266
# Iter: 2010, 	 wass-loss=0.01018, 	 fill-dist=0.02348
# Iter: 2020, 	 wass-loss=0.00961, 	 fill-dist=0.02269
# Iter: 2030, 	 wass-loss=0.0099, 	 fill-dist=0.02313
# Iter: 2040, 	 wass-loss=0.01032, 	 fill-dist=0.02343
# Iter: 2050, 	 wass-loss=0.01092, 	 fill-dist=0.02367
# Iter: 2060, 	 wass-loss=0.01107, 	 fill-dist=0.02377
# Iter: 2070, 	 wass-loss=0.01066, 	 fill-dist=0.02355
# Iter: 2080, 	 wass-loss=0.01151, 	 fill-dist=0.02353
# Iter: 2090, 	 wass-loss=0.01114, 	 fill-dist=0.02375
# Iter: 2100, 	 wass-loss=0.01116, 	 fill-dist=0.02368
# Iter: 2110, 	 wass-loss=0.01284, 	 fill-dist=0.02453
# Iter: 2120, 	 wass-loss=0.01017, 	 fill-dist=0.02395
# Iter: 2130, 	 wass-loss=0.01331, 	 fill-dist=0.02474
# Iter: 2140, 	 wass-loss=0.01667, 	 fill-dist=0.02507
# Iter: 2150, 	 wass-loss=0.01448, 	 fill-dist=0.02425
# Iter: 2160, 	 wass-loss=0.01494, 	 fill-dist=0.02509
# Iter: 2170, 	 wass-loss=0.01513, 	 fill-dist=0.02437
# Iter: 2180, 	 wass-loss=0.01443, 	 fill-dist=0.02505
# Iter: 2190, 	 wass-loss=0.01432, 	 fill-dist=0.0255
# Iter: 2200, 	 wass-loss=0.01704, 	 fill-dist=0.02518
# Iter: 2210, 	 wass-loss=0.01683, 	 fill-dist=0.02547
# Iter: 2220, 	 wass-loss=0.01741, 	 fill-dist=0.02569
# Iter: 2230, 	 wass-loss=0.01789, 	 fill-dist=0.02602
# Iter: 2240, 	 wass-loss=0.01577, 	 fill-dist=0.02586
# Iter: 2250, 	 wass-loss=0.01505, 	 fill-dist=0.02559
# Iter: 2260, 	 wass-loss=0.01551, 	 fill-dist=0.02648
# Iter: 2270, 	 wass-loss=0.01675, 	 fill-dist=0.02579
# Iter: 2280, 	 wass-loss=0.01965, 	 fill-dist=0.02638
# Iter: 2290, 	 wass-loss=0.01613, 	 fill-dist=0.02635
# Iter: 2300, 	 wass-loss=0.01476, 	 fill-dist=0.0265
# Iter: 2310, 	 wass-loss=0.01504, 	 fill-dist=0.02682
# Iter: 2320, 	 wass-loss=0.01273, 	 fill-dist=0.02705
# Iter: 2330, 	 wass-loss=0.01296, 	 fill-dist=0.02695
# Iter: 2340, 	 wass-loss=0.01481, 	 fill-dist=0.02743
# Iter: 2350, 	 wass-loss=0.01615, 	 fill-dist=0.02744
# Iter: 2360, 	 wass-loss=0.01438, 	 fill-dist=0.02805
# Iter: 2370, 	 wass-loss=0.01282, 	 fill-dist=0.02793
# Iter: 2380, 	 wass-loss=0.01381, 	 fill-dist=0.02873
# Iter: 2390, 	 wass-loss=0.0112, 	 fill-dist=0.0286
# Iter: 2400, 	 wass-loss=0.01467, 	 fill-dist=0.0297
# Iter: 2410, 	 wass-loss=0.01324, 	 fill-dist=0.02969
# Iter: 2420, 	 wass-loss=0.01314, 	 fill-dist=0.03045
# Iter: 2430, 	 wass-loss=0.01266, 	 fill-dist=0.03079
# Iter: 2440, 	 wass-loss=0.01293, 	 fill-dist=0.03191
# Iter: 2450, 	 wass-loss=0.013, 	 fill-dist=0.03309
# Iter: 2460, 	 wass-loss=0.0134, 	 fill-dist=0.03275
# Iter: 2470, 	 wass-loss=0.01259, 	 fill-dist=0.03298
# Iter: 2480, 	 wass-loss=0.01294, 	 fill-dist=0.03363
# Iter: 2490, 	 wass-loss=0.01212, 	 fill-dist=0.03299
# Iter: 2500, 	 wass-loss=0.01178, 	 fill-dist=0.03545
# Iter: 2510, 	 wass-loss=0.01269, 	 fill-dist=0.03601
# Iter: 2520, 	 wass-loss=0.01193, 	 fill-dist=0.03626
# Iter: 2530, 	 wass-loss=0.01229, 	 fill-dist=0.03615
# Iter: 2540, 	 wass-loss=0.01217, 	 fill-dist=0.03725
# Iter: 2550, 	 wass-loss=0.01227, 	 fill-dist=0.03847
# Iter: 2560, 	 wass-loss=0.01246, 	 fill-dist=0.03922
# Iter: 2570, 	 wass-loss=0.01177, 	 fill-dist=0.03941
# Iter: 2580, 	 wass-loss=0.01115, 	 fill-dist=0.03942
# Iter: 2590, 	 wass-loss=0.01186, 	 fill-dist=0.04057
# Iter: 2600, 	 wass-loss=0.01178, 	 fill-dist=0.04142
# Iter: 2610, 	 wass-loss=0.01133, 	 fill-dist=0.04191
# Iter: 2620, 	 wass-loss=0.01342, 	 fill-dist=0.04314
# Iter: 2630, 	 wass-loss=0.01208, 	 fill-dist=0.0443
# Iter: 2640, 	 wass-loss=0.01237, 	 fill-dist=0.04449
# Iter: 2650, 	 wass-loss=0.01222, 	 fill-dist=0.04457
# Iter: 2660, 	 wass-loss=0.01094, 	 fill-dist=0.04535
# Iter: 2670, 	 wass-loss=0.01192, 	 fill-dist=0.04608
# Iter: 2680, 	 wass-loss=0.01183, 	 fill-dist=0.04675
# Iter: 2690, 	 wass-loss=0.01332, 	 fill-dist=0.04726
# Iter: 2700, 	 wass-loss=0.01307, 	 fill-dist=0.04764
# Iter: 2710, 	 wass-loss=0.01316, 	 fill-dist=0.04908
# Iter: 2720, 	 wass-loss=0.01325, 	 fill-dist=0.04976
# Iter: 2730, 	 wass-loss=0.01347, 	 fill-dist=0.04945
# Iter: 2740, 	 wass-loss=0.01305, 	 fill-dist=0.04938
# Iter: 2750, 	 wass-loss=0.01376, 	 fill-dist=0.05059
# Iter: 2760, 	 wass-loss=0.01219, 	 fill-dist=0.0496
# Iter: 2770, 	 wass-loss=0.01381, 	 fill-dist=0.05063
# Iter: 2780, 	 wass-loss=0.01401, 	 fill-dist=0.05215
# Iter: 2790, 	 wass-loss=0.01396, 	 fill-dist=0.05163
# Iter: 2800, 	 wass-loss=0.0137, 	 fill-dist=0.05173
# Iter: 2810, 	 wass-loss=0.01419, 	 fill-dist=0.05111
# Iter: 2820, 	 wass-loss=0.01342, 	 fill-dist=0.05127
# Iter: 2830, 	 wass-loss=0.01333, 	 fill-dist=0.05126
# Iter: 2840, 	 wass-loss=0.01438, 	 fill-dist=0.05199
# Iter: 2850, 	 wass-loss=0.01372, 	 fill-dist=0.05208
# Iter: 2860, 	 wass-loss=0.01361, 	 fill-dist=0.05091
# Iter: 2870, 	 wass-loss=0.01324, 	 fill-dist=0.05094
# Iter: 2880, 	 wass-loss=0.01248, 	 fill-dist=0.05
# Iter: 2890, 	 wass-loss=0.01232, 	 fill-dist=0.05002
# Iter: 2900, 	 wass-loss=0.01321, 	 fill-dist=0.05066
# Iter: 2910, 	 wass-loss=0.01217, 	 fill-dist=0.04988
# Iter: 2920, 	 wass-loss=0.01274, 	 fill-dist=0.04987
# Iter: 2930, 	 wass-loss=0.0142, 	 fill-dist=0.05026
# Iter: 2940, 	 wass-loss=0.01274, 	 fill-dist=0.04785
# Iter: 2950, 	 wass-loss=0.01101, 	 fill-dist=0.04722
# Iter: 2960, 	 wass-loss=0.013, 	 fill-dist=0.04864
# Iter: 2970, 	 wass-loss=0.01185, 	 fill-dist=0.0469
# Iter: 2980, 	 wass-loss=0.01067, 	 fill-dist=0.04625
# Iter: 2990, 	 wass-loss=0.01007, 	 fill-dist=0.04525
# Iter: 3000, 	 wass-loss=0.01007, 	 fill-dist=0.04541
# Iter: 3010, 	 wass-loss=0.01103, 	 fill-dist=0.04461
# Iter: 3020, 	 wass-loss=0.01144, 	 fill-dist=0.04403
# Iter: 3030, 	 wass-loss=0.00963, 	 fill-dist=0.04304
# Iter: 3040, 	 wass-loss=0.0102, 	 fill-dist=0.04253
# Iter: 3050, 	 wass-loss=0.0095, 	 fill-dist=0.04246
# Iter: 3060, 	 wass-loss=0.00988, 	 fill-dist=0.04155
# Iter: 3070, 	 wass-loss=0.01024, 	 fill-dist=0.04265
# Iter: 3080, 	 wass-loss=0.00994, 	 fill-dist=0.04106
# Iter: 3090, 	 wass-loss=0.00858, 	 fill-dist=0.04053
# Iter: 3100, 	 wass-loss=0.00948, 	 fill-dist=0.0413
# Iter: 3110, 	 wass-loss=0.00961, 	 fill-dist=0.04128
# Iter: 3120, 	 wass-loss=0.00813, 	 fill-dist=0.0393
# Iter: 3130, 	 wass-loss=0.00889, 	 fill-dist=0.03918
# Iter: 3140, 	 wass-loss=0.00804, 	 fill-dist=0.04013
# Iter: 3150, 	 wass-loss=0.00795, 	 fill-dist=0.03799
# Iter: 3160, 	 wass-loss=0.00873, 	 fill-dist=0.03842
# Iter: 3170, 	 wass-loss=0.00869, 	 fill-dist=0.03855
# Iter: 3180, 	 wass-loss=0.00808, 	 fill-dist=0.03761
# Iter: 3190, 	 wass-loss=0.00809, 	 fill-dist=0.03694
# Iter: 3200, 	 wass-loss=0.00775, 	 fill-dist=0.03684
# Iter: 3210, 	 wass-loss=0.00664, 	 fill-dist=0.03653
# Iter: 3220, 	 wass-loss=0.0076, 	 fill-dist=0.03591
# Iter: 3230, 	 wass-loss=0.00725, 	 fill-dist=0.03669
# Iter: 3240, 	 wass-loss=0.00861, 	 fill-dist=0.03618
# Iter: 3250, 	 wass-loss=0.00721, 	 fill-dist=0.03528
# Iter: 3260, 	 wass-loss=0.00812, 	 fill-dist=0.0355
# Iter: 3270, 	 wass-loss=0.00682, 	 fill-dist=0.03436
# Iter: 3280, 	 wass-loss=0.0064, 	 fill-dist=0.03393
# Iter: 3290, 	 wass-loss=0.00673, 	 fill-dist=0.03424
# Iter: 3300, 	 wass-loss=0.00581, 	 fill-dist=0.03297
# Iter: 3310, 	 wass-loss=0.00656, 	 fill-dist=0.03287
# Iter: 3320, 	 wass-loss=0.00647, 	 fill-dist=0.03305
# Iter: 3330, 	 wass-loss=0.00684, 	 fill-dist=0.03254
# Iter: 3340, 	 wass-loss=0.00584, 	 fill-dist=0.03275
# Iter: 3350, 	 wass-loss=0.0063, 	 fill-dist=0.03188
# Iter: 3360, 	 wass-loss=0.00731, 	 fill-dist=0.03202
# Iter: 3370, 	 wass-loss=0.00632, 	 fill-dist=0.03246
# Iter: 3380, 	 wass-loss=0.00743, 	 fill-dist=0.03177
# Iter: 3390, 	 wass-loss=0.00607, 	 fill-dist=0.03132
# Iter: 3400, 	 wass-loss=0.00783, 	 fill-dist=0.03166
# Iter: 3410, 	 wass-loss=0.00632, 	 fill-dist=0.03129
# Iter: 3420, 	 wass-loss=0.00715, 	 fill-dist=0.03039
# Iter: 3430, 	 wass-loss=0.00615, 	 fill-dist=0.02984
# Iter: 3440, 	 wass-loss=0.0071, 	 fill-dist=0.02983
# Iter: 3450, 	 wass-loss=0.00701, 	 fill-dist=0.03002
# Iter: 3460, 	 wass-loss=0.00834, 	 fill-dist=0.03066
# Iter: 3470, 	 wass-loss=0.00777, 	 fill-dist=0.03032
# Iter: 3480, 	 wass-loss=0.00754, 	 fill-dist=0.03017
# Iter: 3490, 	 wass-loss=0.00773, 	 fill-dist=0.02908
# Iter: 3500, 	 wass-loss=0.00841, 	 fill-dist=0.02926
# Iter: 3510, 	 wass-loss=0.00796, 	 fill-dist=0.02874
# Iter: 3520, 	 wass-loss=0.00697, 	 fill-dist=0.02822
# Iter: 3530, 	 wass-loss=0.00894, 	 fill-dist=0.02867
# Iter: 3540, 	 wass-loss=0.00734, 	 fill-dist=0.02858
# Iter: 3550, 	 wass-loss=0.01001, 	 fill-dist=0.02837
# Iter: 3560, 	 wass-loss=0.00761, 	 fill-dist=0.02816
# Iter: 3570, 	 wass-loss=0.00904, 	 fill-dist=0.02701
# Iter: 3580, 	 wass-loss=0.00742, 	 fill-dist=0.0275
# Iter: 3590, 	 wass-loss=0.00937, 	 fill-dist=0.02751
# Iter: 3600, 	 wass-loss=0.00929, 	 fill-dist=0.02721
# Iter: 3610, 	 wass-loss=0.00943, 	 fill-dist=0.0271
# Iter: 3620, 	 wass-loss=0.00965, 	 fill-dist=0.02693
# Iter: 3630, 	 wass-loss=0.00976, 	 fill-dist=0.02687
# Iter: 3640, 	 wass-loss=0.00873, 	 fill-dist=0.0272
# Iter: 3650, 	 wass-loss=0.00948, 	 fill-dist=0.02701
# Iter: 3660, 	 wass-loss=0.00809, 	 fill-dist=0.02611
# Iter: 3670, 	 wass-loss=0.00899, 	 fill-dist=0.02623
# Iter: 3680, 	 wass-loss=0.01021, 	 fill-dist=0.02607
# Iter: 3690, 	 wass-loss=0.01042, 	 fill-dist=0.02619
# Iter: 3700, 	 wass-loss=0.01053, 	 fill-dist=0.02583
# Iter: 3710, 	 wass-loss=0.0084, 	 fill-dist=0.02572
# Iter: 3720, 	 wass-loss=0.00963, 	 fill-dist=0.02569
# Iter: 3730, 	 wass-loss=0.01294, 	 fill-dist=0.02585
# Iter: 3740, 	 wass-loss=0.00947, 	 fill-dist=0.02577
# Iter: 3750, 	 wass-loss=0.00956, 	 fill-dist=0.02574
# Iter: 3760, 	 wass-loss=0.00976, 	 fill-dist=0.02562
# Iter: 3770, 	 wass-loss=0.00883, 	 fill-dist=0.02556
# Iter: 3780, 	 wass-loss=0.00857, 	 fill-dist=0.02533
# Iter: 3790, 	 wass-loss=0.0103, 	 fill-dist=0.0253
# Iter: 3800, 	 wass-loss=0.01029, 	 fill-dist=0.02487
# Iter: 3810, 	 wass-loss=0.00857, 	 fill-dist=0.02495
# Iter: 3820, 	 wass-loss=0.00887, 	 fill-dist=0.02517
# Iter: 3830, 	 wass-loss=0.00928, 	 fill-dist=0.02487
# Iter: 3840, 	 wass-loss=0.0078, 	 fill-dist=0.02447
# Iter: 3850, 	 wass-loss=0.00988, 	 fill-dist=0.02494
# Iter: 3860, 	 wass-loss=0.00764, 	 fill-dist=0.02489
# Iter: 3870, 	 wass-loss=0.01128, 	 fill-dist=0.02533
# Iter: 3880, 	 wass-loss=0.00671, 	 fill-dist=0.02431
# Iter: 3890, 	 wass-loss=0.00865, 	 fill-dist=0.02475
# Iter: 3900, 	 wass-loss=0.00781, 	 fill-dist=0.02427
# Iter: 3910, 	 wass-loss=0.00726, 	 fill-dist=0.02449
# Iter: 3920, 	 wass-loss=0.0075, 	 fill-dist=0.02441
# Iter: 3930, 	 wass-loss=0.00766, 	 fill-dist=0.02427
# Iter: 3940, 	 wass-loss=0.00813, 	 fill-dist=0.02435
# Iter: 3950, 	 wass-loss=0.00751, 	 fill-dist=0.02442
# Iter: 3960, 	 wass-loss=0.00675, 	 fill-dist=0.02334
# Iter: 3970, 	 wass-loss=0.00613, 	 fill-dist=0.02412
# Iter: 3980, 	 wass-loss=0.00707, 	 fill-dist=0.02412
# Iter: 3990, 	 wass-loss=0.008, 	 fill-dist=0.0238
# Iter: 4000, 	 wass-loss=0.00527, 	 fill-dist=0.02393
# Iter: 4010, 	 wass-loss=0.00562, 	 fill-dist=0.0239
# Iter: 4020, 	 wass-loss=0.00724, 	 fill-dist=0.02416
# Iter: 4030, 	 wass-loss=0.00532, 	 fill-dist=0.0242
# Iter: 4040, 	 wass-loss=0.0065, 	 fill-dist=0.02397
# Iter: 4050, 	 wass-loss=0.00725, 	 fill-dist=0.02396
# Iter: 4060, 	 wass-loss=0.00597, 	 fill-dist=0.02481
# Iter: 4070, 	 wass-loss=0.00534, 	 fill-dist=0.02373
# Iter: 4080, 	 wass-loss=0.00442, 	 fill-dist=0.02405
# Iter: 4090, 	 wass-loss=0.00553, 	 fill-dist=0.02436
# Iter: 4100, 	 wass-loss=0.00554, 	 fill-dist=0.02403
# Iter: 4110, 	 wass-loss=0.0066, 	 fill-dist=0.02389
# Iter: 4120, 	 wass-loss=0.00593, 	 fill-dist=0.02329
# Iter: 4130, 	 wass-loss=0.00436, 	 fill-dist=0.02318
# Iter: 4140, 	 wass-loss=0.00462, 	 fill-dist=0.02398
# Iter: 4150, 	 wass-loss=0.00417, 	 fill-dist=0.02308
# Iter: 4160, 	 wass-loss=0.00552, 	 fill-dist=0.02358
# Iter: 4170, 	 wass-loss=0.00423, 	 fill-dist=0.02325
# Iter: 4180, 	 wass-loss=0.00508, 	 fill-dist=0.02324
# Iter: 4190, 	 wass-loss=0.00529, 	 fill-dist=0.02372
# Iter: 4200, 	 wass-loss=0.00554, 	 fill-dist=0.02356
# Iter: 4210, 	 wass-loss=0.00481, 	 fill-dist=0.02345
# Iter: 4220, 	 wass-loss=0.00431, 	 fill-dist=0.02426
# Iter: 4230, 	 wass-loss=0.00343, 	 fill-dist=0.0237
# Iter: 4240, 	 wass-loss=0.00576, 	 fill-dist=0.0238
# Iter: 4250, 	 wass-loss=0.00412, 	 fill-dist=0.02432
# Iter: 4260, 	 wass-loss=0.00388, 	 fill-dist=0.02412
# Iter: 4270, 	 wass-loss=0.00434, 	 fill-dist=0.02417
# Iter: 4280, 	 wass-loss=0.00356, 	 fill-dist=0.02465
# Iter: 4290, 	 wass-loss=0.00348, 	 fill-dist=0.02466
# Iter: 4300, 	 wass-loss=0.00393, 	 fill-dist=0.02465
# Iter: 4310, 	 wass-loss=0.00382, 	 fill-dist=0.02526
# Iter: 4320, 	 wass-loss=0.00541, 	 fill-dist=0.02563
# Iter: 4330, 	 wass-loss=0.00396, 	 fill-dist=0.02573
# Iter: 4340, 	 wass-loss=0.00575, 	 fill-dist=0.02604
# Iter: 4350, 	 wass-loss=0.00446, 	 fill-dist=0.02652
# Iter: 4360, 	 wass-loss=0.00423, 	 fill-dist=0.0267
# Iter: 4370, 	 wass-loss=0.0032, 	 fill-dist=0.02699
# Iter: 4380, 	 wass-loss=0.00366, 	 fill-dist=0.02682
# Iter: 4390, 	 wass-loss=0.00431, 	 fill-dist=0.02694
# Iter: 4400, 	 wass-loss=0.00358, 	 fill-dist=0.02724
# Iter: 4410, 	 wass-loss=0.00345, 	 fill-dist=0.02765
# Iter: 4420, 	 wass-loss=0.00428, 	 fill-dist=0.02749
# Iter: 4430, 	 wass-loss=0.00313, 	 fill-dist=0.02703
# Iter: 4440, 	 wass-loss=0.00391, 	 fill-dist=0.02763
# Iter: 4450, 	 wass-loss=0.00378, 	 fill-dist=0.02728
# Iter: 4460, 	 wass-loss=0.00312, 	 fill-dist=0.02738
# Iter: 4470, 	 wass-loss=0.00341, 	 fill-dist=0.02726
# Iter: 4480, 	 wass-loss=0.00304, 	 fill-dist=0.02739
# Iter: 4490, 	 wass-loss=0.00364, 	 fill-dist=0.02748
# Iter: 4500, 	 wass-loss=0.00351, 	 fill-dist=0.02801
# Iter: 4510, 	 wass-loss=0.00427, 	 fill-dist=0.02727
# Iter: 4520, 	 wass-loss=0.00365, 	 fill-dist=0.02736
# Iter: 4530, 	 wass-loss=0.00337, 	 fill-dist=0.02764
# Iter: 4540, 	 wass-loss=0.00316, 	 fill-dist=0.02705
# Iter: 4550, 	 wass-loss=0.00306, 	 fill-dist=0.02732
# Iter: 4560, 	 wass-loss=0.00468, 	 fill-dist=0.02691
# Iter: 4570, 	 wass-loss=0.00307, 	 fill-dist=0.02702
# Iter: 4580, 	 wass-loss=0.00396, 	 fill-dist=0.02743
# Iter: 4590, 	 wass-loss=0.00304, 	 fill-dist=0.02701
# Iter: 4600, 	 wass-loss=0.00279, 	 fill-dist=0.02689
# Iter: 4610, 	 wass-loss=0.00396, 	 fill-dist=0.02675
# Iter: 4620, 	 wass-loss=0.00328, 	 fill-dist=0.02684
# Iter: 4630, 	 wass-loss=0.00263, 	 fill-dist=0.02696
# Iter: 4640, 	 wass-loss=0.00363, 	 fill-dist=0.02716
# Iter: 4650, 	 wass-loss=0.00297, 	 fill-dist=0.0278
# Iter: 4660, 	 wass-loss=0.00311, 	 fill-dist=0.02771
# Iter: 4670, 	 wass-loss=0.00328, 	 fill-dist=0.02738
# Iter: 4680, 	 wass-loss=0.00442, 	 fill-dist=0.0269
# Iter: 4690, 	 wass-loss=0.00308, 	 fill-dist=0.02701
# Iter: 4700, 	 wass-loss=0.00305, 	 fill-dist=0.02629
# Iter: 4710, 	 wass-loss=0.00342, 	 fill-dist=0.02639
# Iter: 4720, 	 wass-loss=0.0032, 	 fill-dist=0.02599
# Iter: 4730, 	 wass-loss=0.0027, 	 fill-dist=0.02618
# Iter: 4740, 	 wass-loss=0.00326, 	 fill-dist=0.0257
# Iter: 4750, 	 wass-loss=0.00433, 	 fill-dist=0.02594
# Iter: 4760, 	 wass-loss=0.00406, 	 fill-dist=0.02611
# Iter: 4770, 	 wass-loss=0.00275, 	 fill-dist=0.02581
# Iter: 4780, 	 wass-loss=0.00395, 	 fill-dist=0.02543
# Iter: 4790, 	 wass-loss=0.00366, 	 fill-dist=0.02569
# Iter: 4800, 	 wass-loss=0.00417, 	 fill-dist=0.02568
# Iter: 4810, 	 wass-loss=0.00266, 	 fill-dist=0.02463
# Iter: 4820, 	 wass-loss=0.00304, 	 fill-dist=0.02518
# Iter: 4830, 	 wass-loss=0.00381, 	 fill-dist=0.02509
# Iter: 4840, 	 wass-loss=0.00337, 	 fill-dist=0.02498
# Iter: 4850, 	 wass-loss=0.00372, 	 fill-dist=0.02573
# Iter: 4860, 	 wass-loss=0.00493, 	 fill-dist=0.02624
# Iter: 4870, 	 wass-loss=0.0046, 	 fill-dist=0.02608
# Iter: 4880, 	 wass-loss=0.00387, 	 fill-dist=0.02621
# Iter: 4890, 	 wass-loss=0.00394, 	 fill-dist=0.02561
# Iter: 4900, 	 wass-loss=0.00351, 	 fill-dist=0.02534
# Iter: 4910, 	 wass-loss=0.00501, 	 fill-dist=0.0251
# Iter: 4920, 	 wass-loss=0.00485, 	 fill-dist=0.02458
# Iter: 4930, 	 wass-loss=0.00387, 	 fill-dist=0.02508
# Iter: 4940, 	 wass-loss=0.00449, 	 fill-dist=0.02562
# Iter: 4950, 	 wass-loss=0.00473, 	 fill-dist=0.02631
# Iter: 4960, 	 wass-loss=0.00403, 	 fill-dist=0.02671
# Iter: 4970, 	 wass-loss=0.00455, 	 fill-dist=0.02684
# Iter: 4980, 	 wass-loss=0.00334, 	 fill-dist=0.0262
# Iter: 4990, 	 wass-loss=0.00451, 	 fill-dist=0.02652
# Iter: 5000, 	 wass-loss=0.00374, 	 fill-dist=0.02653
# Iter: 5010, 	 wass-loss=0.0042, 	 fill-dist=0.02654
# Iter: 5020, 	 wass-loss=0.00405, 	 fill-dist=0.02635
# Iter: 5030, 	 wass-loss=0.00475, 	 fill-dist=0.02713
# Iter: 5040, 	 wass-loss=0.00376, 	 fill-dist=0.02715
# Iter: 5050, 	 wass-loss=0.00439, 	 fill-dist=0.02736
# Iter: 5060, 	 wass-loss=0.00503, 	 fill-dist=0.02727
# Iter: 5070, 	 wass-loss=0.00469, 	 fill-dist=0.02711
# Iter: 5080, 	 wass-loss=0.00473, 	 fill-dist=0.02756
# Iter: 5090, 	 wass-loss=0.00381, 	 fill-dist=0.02735
# Iter: 5100, 	 wass-loss=0.00524, 	 fill-dist=0.02724
# Iter: 5110, 	 wass-loss=0.00404, 	 fill-dist=0.02765
# Iter: 5120, 	 wass-loss=0.00396, 	 fill-dist=0.02731
# Iter: 5130, 	 wass-loss=0.00359, 	 fill-dist=0.02815
# Iter: 5140, 	 wass-loss=0.00545, 	 fill-dist=0.02819
# Iter: 5150, 	 wass-loss=0.00491, 	 fill-dist=0.02797
# Iter: 5160, 	 wass-loss=0.00476, 	 fill-dist=0.02804
# Iter: 5170, 	 wass-loss=0.00376, 	 fill-dist=0.02806
# Iter: 5180, 	 wass-loss=0.00443, 	 fill-dist=0.02814
# Iter: 5190, 	 wass-loss=0.00471, 	 fill-dist=0.0275
# Iter: 5200, 	 wass-loss=0.00363, 	 fill-dist=0.02674
# Iter: 5210, 	 wass-loss=0.00368, 	 fill-dist=0.02637
# Iter: 5220, 	 wass-loss=0.00361, 	 fill-dist=0.02649
# Iter: 5230, 	 wass-loss=0.00427, 	 fill-dist=0.02779
# Iter: 5240, 	 wass-loss=0.00385, 	 fill-dist=0.02838
# Iter: 5250, 	 wass-loss=0.00406, 	 fill-dist=0.02853
# Iter: 5260, 	 wass-loss=0.00407, 	 fill-dist=0.02765
# Iter: 5270, 	 wass-loss=0.00365, 	 fill-dist=0.02623
# Iter: 5280, 	 wass-loss=0.00308, 	 fill-dist=0.02528
# Iter: 5290, 	 wass-loss=0.00415, 	 fill-dist=0.02604
# Iter: 5300, 	 wass-loss=0.00348, 	 fill-dist=0.02682
# Iter: 5310, 	 wass-loss=0.00394, 	 fill-dist=0.02908
# Iter: 5320, 	 wass-loss=0.00384, 	 fill-dist=0.02856
# Iter: 5330, 	 wass-loss=0.00388, 	 fill-dist=0.02745
# Iter: 5340, 	 wass-loss=0.00407, 	 fill-dist=0.02673
# Iter: 5350, 	 wass-loss=0.00387, 	 fill-dist=0.02575
# Iter: 5360, 	 wass-loss=0.00509, 	 fill-dist=0.02618
# Iter: 5370, 	 wass-loss=0.00377, 	 fill-dist=0.02753
# Iter: 5380, 	 wass-loss=0.00391, 	 fill-dist=0.02804
# Iter: 5390, 	 wass-loss=0.00365, 	 fill-dist=0.02844
# Iter: 5400, 	 wass-loss=0.00424, 	 fill-dist=0.02725
# Iter: 5410, 	 wass-loss=0.00289, 	 fill-dist=0.02626
# Iter: 5420, 	 wass-loss=0.0027, 	 fill-dist=0.02571
# Iter: 5430, 	 wass-loss=0.00283, 	 fill-dist=0.02655
# Iter: 5440, 	 wass-loss=0.00309, 	 fill-dist=0.02658
# Iter: 5450, 	 wass-loss=0.00309, 	 fill-dist=0.02686
# Iter: 5460, 	 wass-loss=0.00307, 	 fill-dist=0.0276
# Iter: 5470, 	 wass-loss=0.00264, 	 fill-dist=0.02756
# Iter: 5480, 	 wass-loss=0.00361, 	 fill-dist=0.0268
# Iter: 5490, 	 wass-loss=0.00384, 	 fill-dist=0.02551
# Iter: 5500, 	 wass-loss=0.00316, 	 fill-dist=0.02525
# Iter: 5510, 	 wass-loss=0.00284, 	 fill-dist=0.02646
# Iter: 5520, 	 wass-loss=0.00331, 	 fill-dist=0.02742
# Iter: 5530, 	 wass-loss=0.00364, 	 fill-dist=0.02794
# Iter: 5540, 	 wass-loss=0.00288, 	 fill-dist=0.02787
# Iter: 5550, 	 wass-loss=0.00426, 	 fill-dist=0.02708
# Iter: 5560, 	 wass-loss=0.00378, 	 fill-dist=0.02624
# Iter: 5570, 	 wass-loss=0.00322, 	 fill-dist=0.02587
# Iter: 5580, 	 wass-loss=0.00303, 	 fill-dist=0.02648
# Iter: 5590, 	 wass-loss=0.00352, 	 fill-dist=0.0275
# Iter: 5600, 	 wass-loss=0.0033, 	 fill-dist=0.02776
# Iter: 5610, 	 wass-loss=0.00297, 	 fill-dist=0.02822
# Iter: 5620, 	 wass-loss=0.00329, 	 fill-dist=0.02725
# Iter: 5630, 	 wass-loss=0.00282, 	 fill-dist=0.02682
# Iter: 5640, 	 wass-loss=0.00312, 	 fill-dist=0.02685
# Iter: 5650, 	 wass-loss=0.00395, 	 fill-dist=0.02652
# Iter: 5660, 	 wass-loss=0.00373, 	 fill-dist=0.027
# Iter: 5670, 	 wass-loss=0.00393, 	 fill-dist=0.02784
# Iter: 5680, 	 wass-loss=0.00341, 	 fill-dist=0.02746
# Iter: 5690, 	 wass-loss=0.00332, 	 fill-dist=0.02761
# Iter: 5700, 	 wass-loss=0.00295, 	 fill-dist=0.02696
# Iter: 5710, 	 wass-loss=0.00302, 	 fill-dist=0.02684
# Iter: 5720, 	 wass-loss=0.00392, 	 fill-dist=0.02803
# Iter: 5730, 	 wass-loss=0.00382, 	 fill-dist=0.02844
# Iter: 5740, 	 wass-loss=0.00306, 	 fill-dist=0.02644
# Iter: 5750, 	 wass-loss=0.00341, 	 fill-dist=0.02582
# Iter: 5760, 	 wass-loss=0.00423, 	 fill-dist=0.02615
# Iter: 5770, 	 wass-loss=0.00284, 	 fill-dist=0.02752
# Iter: 5780, 	 wass-loss=0.00353, 	 fill-dist=0.02914
# Iter: 5790, 	 wass-loss=0.00381, 	 fill-dist=0.02882
# Iter: 5800, 	 wass-loss=0.00316, 	 fill-dist=0.02717
# Iter: 5810, 	 wass-loss=0.00413, 	 fill-dist=0.02752
# Iter: 5820, 	 wass-loss=0.00357, 	 fill-dist=0.02631
# Iter: 5830, 	 wass-loss=0.00379, 	 fill-dist=0.02777
# Iter: 5840, 	 wass-loss=0.00495, 	 fill-dist=0.02954
# Iter: 5850, 	 wass-loss=0.00424, 	 fill-dist=0.03017
# Iter: 5860, 	 wass-loss=0.0039, 	 fill-dist=0.02841
# Iter: 5870, 	 wass-loss=0.00335, 	 fill-dist=0.02723
# Iter: 5880, 	 wass-loss=0.00277, 	 fill-dist=0.0268
# Iter: 5890, 	 wass-loss=0.00324, 	 fill-dist=0.02757
# Iter: 5900, 	 wass-loss=0.00383, 	 fill-dist=0.02851
# Iter: 5910, 	 wass-loss=0.0032, 	 fill-dist=0.02827
# Iter: 5920, 	 wass-loss=0.00344, 	 fill-dist=0.02764
# Iter: 5930, 	 wass-loss=0.00389, 	 fill-dist=0.02747
# Iter: 5940, 	 wass-loss=0.00383, 	 fill-dist=0.02866
# Iter: 5950, 	 wass-loss=0.00379, 	 fill-dist=0.02923
# Iter: 5960, 	 wass-loss=0.00469, 	 fill-dist=0.02912
# Iter: 5970, 	 wass-loss=0.00348, 	 fill-dist=0.02744
# Iter: 5980, 	 wass-loss=0.00307, 	 fill-dist=0.02705
# Iter: 5990, 	 wass-loss=0.00314, 	 fill-dist=0.0282
# Iter: 6000, 	 wass-loss=0.00445, 	 fill-dist=0.02938
# Iter: 6010, 	 wass-loss=0.00537, 	 fill-dist=0.02966
# Iter: 6020, 	 wass-loss=0.00316, 	 fill-dist=0.02777
# Iter: 6030, 	 wass-loss=0.00367, 	 fill-dist=0.02743
# Iter: 6040, 	 wass-loss=0.00492, 	 fill-dist=0.02853
# Iter: 6050, 	 wass-loss=0.00335, 	 fill-dist=0.02889
# Iter: 6060, 	 wass-loss=0.00421, 	 fill-dist=0.02889
# Iter: 6070, 	 wass-loss=0.00292, 	 fill-dist=0.02787
# Iter: 6080, 	 wass-loss=0.00355, 	 fill-dist=0.0277
# Iter: 6090, 	 wass-loss=0.00345, 	 fill-dist=0.02904
# Iter: 6100, 	 wass-loss=0.00342, 	 fill-dist=0.02986
# Iter: 6110, 	 wass-loss=0.00435, 	 fill-dist=0.02906
# Iter: 6120, 	 wass-loss=0.00437, 	 fill-dist=0.02814
# Iter: 6130, 	 wass-loss=0.00322, 	 fill-dist=0.02885
# Iter: 6140, 	 wass-loss=0.00381, 	 fill-dist=0.0295
# Iter: 6150, 	 wass-loss=0.00327, 	 fill-dist=0.02885
# Iter: 6160, 	 wass-loss=0.00391, 	 fill-dist=0.02747
# Iter: 6170, 	 wass-loss=0.00304, 	 fill-dist=0.0278
# Iter: 6180, 	 wass-loss=0.00321, 	 fill-dist=0.02937
# Iter: 6190, 	 wass-loss=0.00461, 	 fill-dist=0.02981
# Iter: 6200, 	 wass-loss=0.00473, 	 fill-dist=0.02817
# Iter: 6210, 	 wass-loss=0.00371, 	 fill-dist=0.02683
# Iter: 6220, 	 wass-loss=0.0037, 	 fill-dist=0.02911
# Iter: 6230, 	 wass-loss=0.00387, 	 fill-dist=0.03056
# Iter: 6240, 	 wass-loss=0.00363, 	 fill-dist=0.02875
# Iter: 6250, 	 wass-loss=0.00267, 	 fill-dist=0.0265
# Iter: 6260, 	 wass-loss=0.00375, 	 fill-dist=0.02663
# Iter: 6270, 	 wass-loss=0.0033, 	 fill-dist=0.02779
# Iter: 6280, 	 wass-loss=0.00406, 	 fill-dist=0.02998
# Iter: 6290, 	 wass-loss=0.00361, 	 fill-dist=0.02876
# Iter: 6300, 	 wass-loss=0.00309, 	 fill-dist=0.02689
# Iter: 6310, 	 wass-loss=0.00324, 	 fill-dist=0.02741
# Iter: 6320, 	 wass-loss=0.00417, 	 fill-dist=0.02895
# Iter: 6330, 	 wass-loss=0.00466, 	 fill-dist=0.02999
# Iter: 6340, 	 wass-loss=0.00299, 	 fill-dist=0.02834
# Iter: 6350, 	 wass-loss=0.00323, 	 fill-dist=0.02737
# Iter: 6360, 	 wass-loss=0.00323, 	 fill-dist=0.02724
# Iter: 6370, 	 wass-loss=0.0044, 	 fill-dist=0.02918
# Iter: 6380, 	 wass-loss=0.00334, 	 fill-dist=0.02924
# Iter: 6390, 	 wass-loss=0.0046, 	 fill-dist=0.02747
# Iter: 6400, 	 wass-loss=0.00305, 	 fill-dist=0.02693
# Iter: 6410, 	 wass-loss=0.00405, 	 fill-dist=0.0288
# Iter: 6420, 	 wass-loss=0.00316, 	 fill-dist=0.0291
# Iter: 6430, 	 wass-loss=0.00389, 	 fill-dist=0.02801
# Iter: 6440, 	 wass-loss=0.0043, 	 fill-dist=0.02614
# Iter: 6450, 	 wass-loss=0.00305, 	 fill-dist=0.02671
# Iter: 6460, 	 wass-loss=0.00461, 	 fill-dist=0.02895
# Iter: 6470, 	 wass-loss=0.00366, 	 fill-dist=0.03013
# Iter: 6480, 	 wass-loss=0.00353, 	 fill-dist=0.0283
# Iter: 6490, 	 wass-loss=0.00509, 	 fill-dist=0.02622
# Iter: 6500, 	 wass-loss=0.005, 	 fill-dist=0.027
# Iter: 6510, 	 wass-loss=0.00326, 	 fill-dist=0.02916
# Iter: 6520, 	 wass-loss=0.00405, 	 fill-dist=0.03042
# Iter: 6530, 	 wass-loss=0.00343, 	 fill-dist=0.02817
# Iter: 6540, 	 wass-loss=0.00344, 	 fill-dist=0.02624
# Iter: 6550, 	 wass-loss=0.00324, 	 fill-dist=0.02603
# Iter: 6560, 	 wass-loss=0.00357, 	 fill-dist=0.02861
# Iter: 6570, 	 wass-loss=0.00411, 	 fill-dist=0.03111
# Iter: 6580, 	 wass-loss=0.00351, 	 fill-dist=0.02927
# Iter: 6590, 	 wass-loss=0.00288, 	 fill-dist=0.02595
# Iter: 6600, 	 wass-loss=0.00397, 	 fill-dist=0.02444
# Iter: 6610, 	 wass-loss=0.00328, 	 fill-dist=0.02656
# Iter: 6620, 	 wass-loss=0.00419, 	 fill-dist=0.03022
# Iter: 6630, 	 wass-loss=0.00417, 	 fill-dist=0.03129
# Iter: 6640, 	 wass-loss=0.00339, 	 fill-dist=0.02864
# Iter: 6650, 	 wass-loss=0.00576, 	 fill-dist=0.02683
# Iter: 6660, 	 wass-loss=0.00416, 	 fill-dist=0.02553
# Iter: 6670, 	 wass-loss=0.00377, 	 fill-dist=0.02673
# Iter: 6680, 	 wass-loss=0.00479, 	 fill-dist=0.02956
# Iter: 6690, 	 wass-loss=0.00393, 	 fill-dist=0.03064
# Iter: 6700, 	 wass-loss=0.00402, 	 fill-dist=0.02946
# Iter: 6710, 	 wass-loss=0.00308, 	 fill-dist=0.0266
# Iter: 6720, 	 wass-loss=0.00355, 	 fill-dist=0.02657
# Iter: 6730, 	 wass-loss=0.00263, 	 fill-dist=0.0272
# Iter: 6740, 	 wass-loss=0.00428, 	 fill-dist=0.02895
# Iter: 6750, 	 wass-loss=0.00406, 	 fill-dist=0.03092
# Iter: 6760, 	 wass-loss=0.00398, 	 fill-dist=0.02881
# Iter: 6770, 	 wass-loss=0.00473, 	 fill-dist=0.02635
# Iter: 6780, 	 wass-loss=0.00384, 	 fill-dist=0.02682
# Iter: 6790, 	 wass-loss=0.00385, 	 fill-dist=0.03055
# Iter: 6800, 	 wass-loss=0.00344, 	 fill-dist=0.02938
# Iter: 6810, 	 wass-loss=0.0048, 	 fill-dist=0.02762
# Iter: 6820, 	 wass-loss=0.00353, 	 fill-dist=0.02676
# Iter: 6830, 	 wass-loss=0.00289, 	 fill-dist=0.02707
# Iter: 6840, 	 wass-loss=0.00458, 	 fill-dist=0.02871
# Iter: 6850, 	 wass-loss=0.00467, 	 fill-dist=0.03072
# Iter: 6860, 	 wass-loss=0.00476, 	 fill-dist=0.03053
# Iter: 6870, 	 wass-loss=0.00473, 	 fill-dist=0.02802
# Iter: 6880, 	 wass-loss=0.00576, 	 fill-dist=0.02725
# Iter: 6890, 	 wass-loss=0.00542, 	 fill-dist=0.02787
# Iter: 6900, 	 wass-loss=0.00488, 	 fill-dist=0.03124
# Iter: 6910, 	 wass-loss=0.00356, 	 fill-dist=0.02994
# Iter: 6920, 	 wass-loss=0.00277, 	 fill-dist=0.02731
# Iter: 6930, 	 wass-loss=0.00418, 	 fill-dist=0.02557
# Iter: 6940, 	 wass-loss=0.00304, 	 fill-dist=0.02729
# Iter: 6950, 	 wass-loss=0.00383, 	 fill-dist=0.02941
# Iter: 6960, 	 wass-loss=0.0043, 	 fill-dist=0.02954
# Iter: 6970, 	 wass-loss=0.00463, 	 fill-dist=0.02855
# Iter: 6980, 	 wass-loss=0.00365, 	 fill-dist=0.02683
# Iter: 6990, 	 wass-loss=0.00321, 	 fill-dist=0.02709
# Iter: 7000, 	 wass-loss=0.00297, 	 fill-dist=0.02756
# Iter: 7010, 	 wass-loss=0.0045, 	 fill-dist=0.02874
# Iter: 7020, 	 wass-loss=0.00395, 	 fill-dist=0.02736
# Iter: 7030, 	 wass-loss=0.00417, 	 fill-dist=0.02693
# Iter: 7040, 	 wass-loss=0.0032, 	 fill-dist=0.02826
# Iter: 7050, 	 wass-loss=0.00404, 	 fill-dist=0.02837
# Iter: 7060, 	 wass-loss=0.0031, 	 fill-dist=0.02641
# Iter: 7070, 	 wass-loss=0.0036, 	 fill-dist=0.02681
# Iter: 7080, 	 wass-loss=0.00421, 	 fill-dist=0.02845
# Iter: 7090, 	 wass-loss=0.0046, 	 fill-dist=0.02821
# Iter: 7100, 	 wass-loss=0.00361, 	 fill-dist=0.02828
# Iter: 7110, 	 wass-loss=0.00374, 	 fill-dist=0.02785
# Iter: 7120, 	 wass-loss=0.00389, 	 fill-dist=0.02722
# Iter: 7130, 	 wass-loss=0.00317, 	 fill-dist=0.02678
# Iter: 7140, 	 wass-loss=0.00283, 	 fill-dist=0.02755
# Iter: 7150, 	 wass-loss=0.00422, 	 fill-dist=0.02769
# Iter: 7160, 	 wass-loss=0.00349, 	 fill-dist=0.02656
# Iter: 7170, 	 wass-loss=0.00294, 	 fill-dist=0.02744
# Iter: 7180, 	 wass-loss=0.00345, 	 fill-dist=0.02731
# Iter: 7190, 	 wass-loss=0.00361, 	 fill-dist=0.02642
# Iter: 7200, 	 wass-loss=0.00297, 	 fill-dist=0.02603
# Iter: 7210, 	 wass-loss=0.00288, 	 fill-dist=0.02713
# Iter: 7220, 	 wass-loss=0.00406, 	 fill-dist=0.02582
# Iter: 7230, 	 wass-loss=0.00344, 	 fill-dist=0.02582
# Iter: 7240, 	 wass-loss=0.0042, 	 fill-dist=0.02815
# Iter: 7250, 	 wass-loss=0.00291, 	 fill-dist=0.02546
# Iter: 7260, 	 wass-loss=0.0023, 	 fill-dist=0.02433
# Iter: 7270, 	 wass-loss=0.00339, 	 fill-dist=0.02602
# Iter: 7280, 	 wass-loss=0.00332, 	 fill-dist=0.02501
# Iter: 7290, 	 wass-loss=0.00246, 	 fill-dist=0.02465
# Iter: 7300, 	 wass-loss=0.00288, 	 fill-dist=0.02468
# Iter: 7310, 	 wass-loss=0.0029, 	 fill-dist=0.02419
# Iter: 7320, 	 wass-loss=0.00296, 	 fill-dist=0.0258
# Iter: 7330, 	 wass-loss=0.00232, 	 fill-dist=0.02486
# Iter: 7340, 	 wass-loss=0.00228, 	 fill-dist=0.02339
# Iter: 7350, 	 wass-loss=0.00312, 	 fill-dist=0.02519
# Iter: 7360, 	 wass-loss=0.00235, 	 fill-dist=0.02615
# Iter: 7370, 	 wass-loss=0.00306, 	 fill-dist=0.02273
# Iter: 7380, 	 wass-loss=0.00217, 	 fill-dist=0.02291
# Iter: 7390, 	 wass-loss=0.00272, 	 fill-dist=0.02503
# Iter: 7400, 	 wass-loss=0.00207, 	 fill-dist=0.02415
# Iter: 7410, 	 wass-loss=0.00291, 	 fill-dist=0.02179
# Iter: 7420, 	 wass-loss=0.00198, 	 fill-dist=0.02296
# Iter: 7430, 	 wass-loss=0.00281, 	 fill-dist=0.02457
# Iter: 7440, 	 wass-loss=0.00234, 	 fill-dist=0.02247
# Iter: 7450, 	 wass-loss=0.00248, 	 fill-dist=0.02152
# Iter: 7460, 	 wass-loss=0.00304, 	 fill-dist=0.02373
# Iter: 7470, 	 wass-loss=0.00282, 	 fill-dist=0.0228
# Iter: 7480, 	 wass-loss=0.00198, 	 fill-dist=0.02192
# Iter: 7490, 	 wass-loss=0.00162, 	 fill-dist=0.02164
# Iter: 7500, 	 wass-loss=0.00172, 	 fill-dist=0.02239
# Iter: 7510, 	 wass-loss=0.00168, 	 fill-dist=0.02225
# Iter: 7520, 	 wass-loss=0.00188, 	 fill-dist=0.0207
# Iter: 7530, 	 wass-loss=0.00154, 	 fill-dist=0.02057
# Iter: 7540, 	 wass-loss=0.00197, 	 fill-dist=0.02213
# Iter: 7550, 	 wass-loss=0.00166, 	 fill-dist=0.02101
# Iter: 7560, 	 wass-loss=0.00137, 	 fill-dist=0.01962
# Iter: 7570, 	 wass-loss=0.00177, 	 fill-dist=0.02043
# Iter: 7580, 	 wass-loss=0.00204, 	 fill-dist=0.02171
# Iter: 7590, 	 wass-loss=0.00264, 	 fill-dist=0.01994
# Iter: 7600, 	 wass-loss=0.00349, 	 fill-dist=0.0189
# Iter: 7610, 	 wass-loss=0.00133, 	 fill-dist=0.02041
# Iter: 7620, 	 wass-loss=0.00241, 	 fill-dist=0.02097
# Iter: 7630, 	 wass-loss=0.00135, 	 fill-dist=0.01865
# Iter: 7640, 	 wass-loss=0.00191, 	 fill-dist=0.01966
# Iter: 7650, 	 wass-loss=0.00313, 	 fill-dist=0.02177
# Iter: 7660, 	 wass-loss=0.00182, 	 fill-dist=0.01988
# Iter: 7670, 	 wass-loss=0.00196, 	 fill-dist=0.01809
# Iter: 7680, 	 wass-loss=0.00241, 	 fill-dist=0.02007
# Iter: 7690, 	 wass-loss=0.00218, 	 fill-dist=0.0211
# Iter: 7700, 	 wass-loss=0.00163, 	 fill-dist=0.01888
# Iter: 7710, 	 wass-loss=0.00105, 	 fill-dist=0.01829
# Iter: 7720, 	 wass-loss=0.00207, 	 fill-dist=0.02026
# Iter: 7730, 	 wass-loss=0.00231, 	 fill-dist=0.02014
# Iter: 7740, 	 wass-loss=0.0012, 	 fill-dist=0.01849
# Iter: 7750, 	 wass-loss=0.00281, 	 fill-dist=0.01908
# Iter: 7760, 	 wass-loss=0.00146, 	 fill-dist=0.02008
# Iter: 7770, 	 wass-loss=0.00166, 	 fill-dist=0.01967
# Iter: 7780, 	 wass-loss=0.00194, 	 fill-dist=0.01966
# Iter: 7790, 	 wass-loss=0.00301, 	 fill-dist=0.01882
# Iter: 7800, 	 wass-loss=0.00297, 	 fill-dist=0.02016
# Iter: 7810, 	 wass-loss=0.00145, 	 fill-dist=0.01965
# Iter: 7820, 	 wass-loss=0.00362, 	 fill-dist=0.01904
# Iter: 7830, 	 wass-loss=0.00198, 	 fill-dist=0.01881
# Iter: 7840, 	 wass-loss=0.00163, 	 fill-dist=0.0198
# Iter: 7850, 	 wass-loss=0.00188, 	 fill-dist=0.02006
# Iter: 7860, 	 wass-loss=0.00192, 	 fill-dist=0.01869
# Iter: 7870, 	 wass-loss=0.00296, 	 fill-dist=0.01864
# Iter: 7880, 	 wass-loss=0.00189, 	 fill-dist=0.01894
# Iter: 7890, 	 wass-loss=0.00303, 	 fill-dist=0.02056
# Iter: 7900, 	 wass-loss=0.00155, 	 fill-dist=0.01884
# Iter: 7910, 	 wass-loss=0.00133, 	 fill-dist=0.01841
# Iter: 7920, 	 wass-loss=0.0012, 	 fill-dist=0.01828
# Iter: 7930, 	 wass-loss=0.00288, 	 fill-dist=0.01959
# Iter: 7940, 	 wass-loss=0.00168, 	 fill-dist=0.01859
# Iter: 7950, 	 wass-loss=0.00261, 	 fill-dist=0.01852
# Iter: 7960, 	 wass-loss=0.00133, 	 fill-dist=0.019
# Iter: 7970, 	 wass-loss=0.00242, 	 fill-dist=0.01994
# Iter: 7980, 	 wass-loss=0.00182, 	 fill-dist=0.01917
# Iter: 7990, 	 wass-loss=0.00206, 	 fill-dist=0.01851
# Iter: 8000, 	 wass-loss=0.00132, 	 fill-dist=0.01845
# Iter: 8010, 	 wass-loss=0.00288, 	 fill-dist=0.01961
# Iter: 8020, 	 wass-loss=0.00299, 	 fill-dist=0.0186
# Iter: 8030, 	 wass-loss=0.00331, 	 fill-dist=0.01907
# Iter: 8040, 	 wass-loss=0.00133, 	 fill-dist=0.01851
# Iter: 8050, 	 wass-loss=0.00145, 	 fill-dist=0.01909
# Iter: 8060, 	 wass-loss=0.00201, 	 fill-dist=0.01876
# Iter: 8070, 	 wass-loss=0.00308, 	 fill-dist=0.01862
# Iter: 8080, 	 wass-loss=0.00096, 	 fill-dist=0.01827
# Iter: 8090, 	 wass-loss=0.0036, 	 fill-dist=0.01882
# Iter: 8100, 	 wass-loss=0.00107, 	 fill-dist=0.0179
# Iter: 8110, 	 wass-loss=0.00146, 	 fill-dist=0.01802
# Iter: 8120, 	 wass-loss=0.00199, 	 fill-dist=0.01818
# Iter: 8130, 	 wass-loss=0.00246, 	 fill-dist=0.0184
# Iter: 8140, 	 wass-loss=0.00139, 	 fill-dist=0.0184
# Iter: 8150, 	 wass-loss=0.00198, 	 fill-dist=0.01829
# Iter: 8160, 	 wass-loss=0.00109, 	 fill-dist=0.01794
# Iter: 8170, 	 wass-loss=0.00157, 	 fill-dist=0.01818
# Iter: 8180, 	 wass-loss=0.00255, 	 fill-dist=0.01817
# Iter: 8190, 	 wass-loss=0.00253, 	 fill-dist=0.01829
# Iter: 8200, 	 wass-loss=0.00188, 	 fill-dist=0.0183
# Iter: 8210, 	 wass-loss=0.00144, 	 fill-dist=0.01753
# Iter: 8220, 	 wass-loss=0.00351, 	 fill-dist=0.01877
# Iter: 8230, 	 wass-loss=0.00148, 	 fill-dist=0.01822
# Iter: 8240, 	 wass-loss=0.00146, 	 fill-dist=0.01777
# Iter: 8250, 	 wass-loss=0.00186, 	 fill-dist=0.01781
# Iter: 8260, 	 wass-loss=0.00143, 	 fill-dist=0.01824
# Iter: 8270, 	 wass-loss=0.00238, 	 fill-dist=0.01759
# Iter: 8280, 	 wass-loss=0.00232, 	 fill-dist=0.01823
# Iter: 8290, 	 wass-loss=0.00159, 	 fill-dist=0.01786
# Iter: 8300, 	 wass-loss=0.00094, 	 fill-dist=0.01732
# Iter: 8310, 	 wass-loss=0.00288, 	 fill-dist=0.01805
# Iter: 8320, 	 wass-loss=0.00312, 	 fill-dist=0.01753
# Iter: 8330, 	 wass-loss=0.00268, 	 fill-dist=0.01878
# Iter: 8340, 	 wass-loss=0.00182, 	 fill-dist=0.01758
# Iter: 8350, 	 wass-loss=0.00243, 	 fill-dist=0.01798
# Iter: 8360, 	 wass-loss=0.00252, 	 fill-dist=0.01856
# Iter: 8370, 	 wass-loss=0.00297, 	 fill-dist=0.01855
# Iter: 8380, 	 wass-loss=0.00143, 	 fill-dist=0.01802
# Iter: 8390, 	 wass-loss=0.0026, 	 fill-dist=0.01849
# Iter: 8400, 	 wass-loss=0.00256, 	 fill-dist=0.01856
# Iter: 8410, 	 wass-loss=0.00222, 	 fill-dist=0.01793
# Iter: 8420, 	 wass-loss=0.00214, 	 fill-dist=0.01788
# Iter: 8430, 	 wass-loss=0.00275, 	 fill-dist=0.01799
# Iter: 8440, 	 wass-loss=0.00365, 	 fill-dist=0.0191
# Iter: 8450, 	 wass-loss=0.00149, 	 fill-dist=0.01692
# Iter: 8460, 	 wass-loss=0.00474, 	 fill-dist=0.0182
# Iter: 8470, 	 wass-loss=0.00193, 	 fill-dist=0.01762
# Iter: 8480, 	 wass-loss=0.00277, 	 fill-dist=0.0189
# Iter: 8490, 	 wass-loss=0.0013, 	 fill-dist=0.01721
# Iter: 8500, 	 wass-loss=0.00266, 	 fill-dist=0.01812
# Iter: 8510, 	 wass-loss=0.00154, 	 fill-dist=0.0171
# Iter: 8520, 	 wass-loss=0.00426, 	 fill-dist=0.01821
# Iter: 8530, 	 wass-loss=0.00288, 	 fill-dist=0.01728
# Iter: 8540, 	 wass-loss=0.00243, 	 fill-dist=0.01744
# Iter: 8550, 	 wass-loss=0.00215, 	 fill-dist=0.01815
# Iter: 8560, 	 wass-loss=0.00149, 	 fill-dist=0.0174
# Iter: 8570, 	 wass-loss=0.00362, 	 fill-dist=0.01775
# Iter: 8580, 	 wass-loss=0.00102, 	 fill-dist=0.01696
# Iter: 8590, 	 wass-loss=0.00366, 	 fill-dist=0.01854
# Iter: 8600, 	 wass-loss=0.00081, 	 fill-dist=0.01699
# Iter: 8610, 	 wass-loss=0.00451, 	 fill-dist=0.01741
# Iter: 8620, 	 wass-loss=0.00169, 	 fill-dist=0.01794
# Iter: 8630, 	 wass-loss=0.00361, 	 fill-dist=0.01802
# Iter: 8640, 	 wass-loss=0.0015, 	 fill-dist=0.01705
# Iter: 8650, 	 wass-loss=0.00152, 	 fill-dist=0.01733
# Iter: 8660, 	 wass-loss=0.00201, 	 fill-dist=0.01731
# Iter: 8670, 	 wass-loss=0.00174, 	 fill-dist=0.01712
# Iter: 8680, 	 wass-loss=0.00195, 	 fill-dist=0.01689
# Iter: 8690, 	 wass-loss=0.00266, 	 fill-dist=0.01726
# Iter: 8700, 	 wass-loss=0.00228, 	 fill-dist=0.01743
# Iter: 8710, 	 wass-loss=0.00161, 	 fill-dist=0.01691
# Iter: 8720, 	 wass-loss=0.00163, 	 fill-dist=0.01746
# Iter: 8730, 	 wass-loss=0.00117, 	 fill-dist=0.01711
# Iter: 8740, 	 wass-loss=0.00309, 	 fill-dist=0.01741
# Iter: 8750, 	 wass-loss=0.0009, 	 fill-dist=0.01697
# Iter: 8760, 	 wass-loss=0.00227, 	 fill-dist=0.01727
# Iter: 8770, 	 wass-loss=0.00135, 	 fill-dist=0.0171
# Iter: 8780, 	 wass-loss=0.00154, 	 fill-dist=0.01679
# Iter: 8790, 	 wass-loss=0.00179, 	 fill-dist=0.01764
# Iter: 8800, 	 wass-loss=0.002, 	 fill-dist=0.01682
# Iter: 8810, 	 wass-loss=0.00173, 	 fill-dist=0.01773
# Iter: 8820, 	 wass-loss=0.00177, 	 fill-dist=0.01748
# Iter: 8830, 	 wass-loss=0.00151, 	 fill-dist=0.01727
# Iter: 8840, 	 wass-loss=0.00084, 	 fill-dist=0.01695
# Iter: 8850, 	 wass-loss=0.00107, 	 fill-dist=0.017
# Iter: 8860, 	 wass-loss=0.00134, 	 fill-dist=0.01688
# Iter: 8870, 	 wass-loss=0.00109, 	 fill-dist=0.01715
# Iter: 8880, 	 wass-loss=0.00089, 	 fill-dist=0.01686
# Iter: 8890, 	 wass-loss=0.00107, 	 fill-dist=0.01676
# Iter: 8900, 	 wass-loss=0.00228, 	 fill-dist=0.01791
# Iter: 8910, 	 wass-loss=0.00281, 	 fill-dist=0.01729
# Iter: 8920, 	 wass-loss=0.00163, 	 fill-dist=0.01775
# Iter: 8930, 	 wass-loss=0.00311, 	 fill-dist=0.01807
# Iter: 8940, 	 wass-loss=0.00115, 	 fill-dist=0.01704
# Iter: 8950, 	 wass-loss=0.00138, 	 fill-dist=0.01724
# Iter: 8960, 	 wass-loss=0.005, 	 fill-dist=0.0191
# Iter: 8970, 	 wass-loss=0.00429, 	 fill-dist=0.01895
# Iter: 8980, 	 wass-loss=0.00376, 	 fill-dist=0.01765
# Iter: 8990, 	 wass-loss=0.00318, 	 fill-dist=0.0178
# Iter: 9000, 	 wass-loss=0.00114, 	 fill-dist=0.01742
# Iter: 9010, 	 wass-loss=0.00302, 	 fill-dist=0.01764
# Iter: 9020, 	 wass-loss=0.00332, 	 fill-dist=0.01903
# Iter: 9030, 	 wass-loss=0.00136, 	 fill-dist=0.01706
# Iter: 9040, 	 wass-loss=0.00369, 	 fill-dist=0.0177
# Iter: 9050, 	 wass-loss=0.00251, 	 fill-dist=0.01803
# Iter: 9060, 	 wass-loss=0.00325, 	 fill-dist=0.0186
# Iter: 9070, 	 wass-loss=0.00573, 	 fill-dist=0.01837
# Iter: 9080, 	 wass-loss=0.00263, 	 fill-dist=0.01755
# Iter: 9090, 	 wass-loss=0.00362, 	 fill-dist=0.01864
# Iter: 9100, 	 wass-loss=0.00378, 	 fill-dist=0.01818
# Iter: 9110, 	 wass-loss=0.00124, 	 fill-dist=0.01712
# Iter: 9120, 	 wass-loss=0.00489, 	 fill-dist=0.01946
# Iter: 9130, 	 wass-loss=0.0013, 	 fill-dist=0.0176
# Iter: 9140, 	 wass-loss=0.00225, 	 fill-dist=0.01778
# Iter: 9150, 	 wass-loss=0.00255, 	 fill-dist=0.01801
# Iter: 9160, 	 wass-loss=0.00199, 	 fill-dist=0.01726
# Iter: 9170, 	 wass-loss=0.00333, 	 fill-dist=0.0178
# Iter: 9180, 	 wass-loss=0.00183, 	 fill-dist=0.01653
# Iter: 9190, 	 wass-loss=0.00454, 	 fill-dist=0.01923
# Iter: 9200, 	 wass-loss=0.00152, 	 fill-dist=0.01722
# Iter: 9210, 	 wass-loss=0.00265, 	 fill-dist=0.01732
# Iter: 9220, 	 wass-loss=0.00445, 	 fill-dist=0.01876
# Iter: 9230, 	 wass-loss=0.00126, 	 fill-dist=0.01666
# Iter: 9240, 	 wass-loss=0.00847, 	 fill-dist=0.0182
# Iter: 9250, 	 wass-loss=0.00178, 	 fill-dist=0.0173
# Iter: 9260, 	 wass-loss=0.00447, 	 fill-dist=0.01872
# Iter: 9270, 	 wass-loss=0.00223, 	 fill-dist=0.01748
# Iter: 9280, 	 wass-loss=0.00112, 	 fill-dist=0.01725
# Iter: 9290, 	 wass-loss=0.0029, 	 fill-dist=0.01889
# Iter: 9300, 	 wass-loss=0.00098, 	 fill-dist=0.01643
# Iter: 9310, 	 wass-loss=0.00423, 	 fill-dist=0.0174
# Iter: 9320, 	 wass-loss=0.00097, 	 fill-dist=0.01687
# Iter: 9330, 	 wass-loss=0.00338, 	 fill-dist=0.0184
# Iter: 9340, 	 wass-loss=0.00225, 	 fill-dist=0.01748
# Iter: 9350, 	 wass-loss=0.00228, 	 fill-dist=0.01694
# Iter: 9360, 	 wass-loss=0.00544, 	 fill-dist=0.01868
# Iter: 9370, 	 wass-loss=0.00104, 	 fill-dist=0.01648
# Iter: 9380, 	 wass-loss=0.00513, 	 fill-dist=0.01761
# Iter: 9390, 	 wass-loss=0.0021, 	 fill-dist=0.0176
# Iter: 9400, 	 wass-loss=0.00272, 	 fill-dist=0.01741
# Iter: 9410, 	 wass-loss=0.00357, 	 fill-dist=0.01797
# Iter: 9420, 	 wass-loss=0.0009, 	 fill-dist=0.01687
# Iter: 9430, 	 wass-loss=0.0032, 	 fill-dist=0.01862
# Iter: 9440, 	 wass-loss=0.00206, 	 fill-dist=0.01696
# Iter: 9450, 	 wass-loss=0.00138, 	 fill-dist=0.0171
# Iter: 9460, 	 wass-loss=0.0038, 	 fill-dist=0.01822
# Iter: 9470, 	 wass-loss=0.00124, 	 fill-dist=0.01713
# Iter: 9480, 	 wass-loss=0.0025, 	 fill-dist=0.01743
# Iter: 9490, 	 wass-loss=0.00224, 	 fill-dist=0.01726
# Iter: 9500, 	 wass-loss=0.00216, 	 fill-dist=0.01708
# Iter: 9510, 	 wass-loss=0.00382, 	 fill-dist=0.01828
# Iter: 9520, 	 wass-loss=0.00141, 	 fill-dist=0.01745
# Iter: 9530, 	 wass-loss=0.00194, 	 fill-dist=0.0176
# Iter: 9540, 	 wass-loss=0.00282, 	 fill-dist=0.01752
# Iter: 9550, 	 wass-loss=0.00134, 	 fill-dist=0.01698
# Iter: 9560, 	 wass-loss=0.00337, 	 fill-dist=0.01767
# Iter: 9570, 	 wass-loss=0.00218, 	 fill-dist=0.01761
# Iter: 9580, 	 wass-loss=0.00105, 	 fill-dist=0.01679
# Iter: 9590, 	 wass-loss=0.00349, 	 fill-dist=0.01856
# Iter: 9600, 	 wass-loss=0.00244, 	 fill-dist=0.01719
# Iter: 9610, 	 wass-loss=0.00173, 	 fill-dist=0.01671
# Iter: 9620, 	 wass-loss=0.00167, 	 fill-dist=0.0183
# Iter: 9630, 	 wass-loss=0.00173, 	 fill-dist=0.01745
# Iter: 9640, 	 wass-loss=0.00114, 	 fill-dist=0.01692
# Iter: 9650, 	 wass-loss=0.00407, 	 fill-dist=0.01826
# Iter: 9660, 	 wass-loss=0.00163, 	 fill-dist=0.0168
# Iter: 9670, 	 wass-loss=0.00148, 	 fill-dist=0.01669
# Iter: 9680, 	 wass-loss=0.00281, 	 fill-dist=0.01793
# Iter: 9690, 	 wass-loss=0.00155, 	 fill-dist=0.01764
# Iter: 9700, 	 wass-loss=0.0015, 	 fill-dist=0.01756
# Iter: 9710, 	 wass-loss=0.00393, 	 fill-dist=0.01873
# Iter: 9720, 	 wass-loss=0.00223, 	 fill-dist=0.01735
# Iter: 9730, 	 wass-loss=0.00111, 	 fill-dist=0.01717
# Iter: 9740, 	 wass-loss=0.00367, 	 fill-dist=0.01792
# Iter: 9750, 	 wass-loss=0.00195, 	 fill-dist=0.01716
# Iter: 9760, 	 wass-loss=0.00089, 	 fill-dist=0.01708
# Iter: 9770, 	 wass-loss=0.00187, 	 fill-dist=0.01769
# Iter: 9780, 	 wass-loss=0.00358, 	 fill-dist=0.01737
# Iter: 9790, 	 wass-loss=0.00175, 	 fill-dist=0.01724
# Iter: 9800, 	 wass-loss=0.00124, 	 fill-dist=0.01713
# Iter: 9810, 	 wass-loss=0.00158, 	 fill-dist=0.01696
# Iter: 9820, 	 wass-loss=0.00171, 	 fill-dist=0.01762
# Iter: 9830, 	 wass-loss=0.00092, 	 fill-dist=0.01698
# Iter: 9840, 	 wass-loss=0.00116, 	 fill-dist=0.01683
# Iter: 9850, 	 wass-loss=0.00248, 	 fill-dist=0.01781
# Iter: 9860, 	 wass-loss=0.00188, 	 fill-dist=0.01729
# Iter: 9870, 	 wass-loss=0.00127, 	 fill-dist=0.01716
# Iter: 9880, 	 wass-loss=0.00096, 	 fill-dist=0.01709
# Iter: 9890, 	 wass-loss=0.00315, 	 fill-dist=0.01752
# Iter: 9900, 	 wass-loss=0.00124, 	 fill-dist=0.01754
# Iter: 9910, 	 wass-loss=0.00149, 	 fill-dist=0.0169
# Iter: 9920, 	 wass-loss=0.00293, 	 fill-dist=0.01782
# Iter: 9930, 	 wass-loss=0.00129, 	 fill-dist=0.01728
# Iter: 9940, 	 wass-loss=0.002, 	 fill-dist=0.01791
# Iter: 9950, 	 wass-loss=0.00166, 	 fill-dist=0.01716
# Iter: 9960, 	 wass-loss=0.00161, 	 fill-dist=0.01699
# Iter: 9970, 	 wass-loss=0.00259, 	 fill-dist=0.01768
# Iter: 9980, 	 wass-loss=0.00255, 	 fill-dist=0.01819
# Iter: 9990, 	 wass-loss=0.00286, 	 fill-dist=0.01776
# Text(0.5, 0, 'Iterations')

# %% [markdown]
# ## Plot trajectories of generated samples along iterations

# %%
torch.manual_seed(seed) # make chunk execution consistent 

# ivisu = [0, 50, 100, 500, n_iter-3000, n_iter-2000, n_iter-1000, n_iter-500, n_iter-1]
ivisu = [0, 1000, 2500, 5000, n_iter-4000, n_iter-3000, n_iter-2000, n_iter-1000, n_iter-1]


pl.figure(3, (10, 10))

for i in range(9):
    
    pl.subplot(3, 3, i + 1)

    # use the distances to map to colors
    progression = np.linspace(0, 1, n_visu)  # Normalize progression to [0, 1], not used here 
    
    pl.scatter(xd[:, 0], xd[:, 1], label='Data samples from $\mu_d$', alpha=0.2)
    pl.scatter(xvisu[ivisu[i], :, 0], xvisu[ivisu[i], :, 1], 
               label='Data samples from $G\#\eta_d$', 
               alpha=.5,
                #c = progression,
                #cmap='Oranges'
                )

    pl.xticks(())
    pl.yticks(())
    pl.title(f'Iter. {ivisu[i]}, \n Wass-Loss={round(losses[ivisu[i]], 4)}, \n Fill-Distance={round(fill_losses[ivisu[i]], 4)}')
    if i == 0:
        pl.legend()
    
# adjust the spacing
pl.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.3, hspace=0.3)
